# %% [markdown]
# <a href="https://colab.research.google.com/github/Hisham-ghanayem/Complete-Python-3-Bootcamp/blob/master/Advanced_AI_Modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter

# %%
lst = [1,2,2,2,2,3,3,3,1,2,1,12,3,2,32,1,21,1,223,1]

# %%
Counter(lst)
# Out:
# Counter({1: 6, 2: 6, 3: 4, 12: 1, 32: 1, 21: 1, 223: 1})

# %%
Counter('aabsbsbsbhshhbbsbs')
# Out:
# Counter({'a': 2, 'b': 7, 's': 6, 'h': 3})

# %%
sentence = "How many times does each word show up in this sentence with a word"

# %%
Counter(sentence.lower().split())
# Out:
# Counter({'how': 1,
#          'many': 1,
#          'times': 1,
#          'does': 1,
#          'each': 1,
#          'word': 2,
#          'show': 1,
#          'up': 1,
#          'in': 1,
#          'this': 1,
#          'sentence': 1,
#          'with': 1,
#          'a': 1})

# %%
letters = 'aaabbbbbccccddddddddd'

# %%
c=Counter(letters)

# %%
c
# Out:
# Counter({'a': 3, 'b': 5, 'c': 4, 'd': 9})

# %%
c.most_common()
# Out:
# [('d', 9), ('b', 5), ('c', 4), ('a', 3)]

# %%
from collections import defaultdict

# %%
d = {'a':10}

# %%
d
# Out:
# {'a': 10}

# %%
d['a']
# Out:
# 10

# %%
d['Worong']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_15206/565400656.py in <cell line: 0>()
# ----> 1 d['Worong']
#
# KeyError: 'Worong'

# %%
d = defaultdict(lambda:0)

# %%
d['correct'] = 100

# %%
d['correct']
# Out:
# 100

# %%
d['Wrong Key']
# Out:
# 0

# %%
from collections import namedtuple

# %%
Dog = namedtuple('Dog',['age','breed','name'])

# %%
sammy = Dog(age = 5,breed='Husky',name='Sam')

# %%
type(sammy)
# Out:
# __main__.Dog

# %%
sammy
# Out:
# Dog(age=5, breed='Husky', name='Sam')

# %%
sammy.age
# Out:
# 5
